# %% [markdown]
# #COVID-19
#
# Dados informativos e casos do coronavírus casos confirmados e óbitos obtidos dos boletins das Secretarias Estaduais de Saúde.
#
# dados retirados do site 'brasil.io'
# link:https://brasil.io/dataset/covid19/caso
#
# Dados capturados em 23 de Abril de 2020. Importação dos dados feita em 23 de Abril de 2020 às 18:22:36.

# %%
#importando bibliotecas
import pandas as pd
# %matplotlib inline

# %%
#DataFrame
df = pd.read_csv('Covid_19_Brasil_io.csv')
df
# Out:
#              date state        city place_type  confirmed  deaths  is_last  \
# 0      2020-04-23    PA  Abaetetuba       city          6       0     True
# 1      2020-04-23    PA       Acará       city          2       0     True
# 2      2020-04-23    PA        Afuá       city          1       0     True
# 3      2020-04-23    PA    Alenquer       city          1       0     True
# 4      2020-04-23    PA    Altamira       city          8       0     True
# ...           ...   ...         ...        ...        ...     ...      ...
# 26012  2020-02-27    SP         NaN      state          1       0    False
# 26013  2020-02-26    SP   São Paulo       city          1       0    False
# 26014  2020-02-26    SP         NaN      state          1       0    False
# 26015  2020-02-25    SP   São Paulo       city          1       0    False
# 26016  2020-02-25    SP         NaN      state          1       0    False
#
#        estimated_population_2019  city_ibge_code  \
# ...

# %%
df.columns
# Out:
# Index(['date', 'state', 'city', 'place_type', 'confirmed', 'deaths', 'is_last',
#        'estimated_population_2019', 'city_ibge_code',
#        'confirmed_per_100k_inhabitants', 'death_rate'],
#       dtype='object')

# %%
df.shape
# Out:
# (26017, 11)

# %%
df.head()
# Out:
#          date state        city place_type  confirmed  deaths  is_last  \
# 0  2020-04-23    PA  Abaetetuba       city          6       0     True
# 1  2020-04-23    PA       Acará       city          2       0     True
# 2  2020-04-23    PA        Afuá       city          1       0     True
# 3  2020-04-23    PA    Alenquer       city          1       0     True
# 4  2020-04-23    PA    Altamira       city          8       0     True
#
#    estimated_population_2019  city_ibge_code  confirmed_per_100k_inhabitants  \
# 0                   157698.0       1500107.0                         3.80474
# 1                    55591.0       1500206.0                         3.59770
# 2                    39218.0       1500305.0                         2.54985
# 3                    56789.0       1500404.0                         1.76090
# 4                   114594.0       1500602.0                         6.98117
#
#    death_rate
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
df.tail()
# Out:
#              date state       city place_type  confirmed  deaths  is_last  \
# 26012  2020-02-27    SP        NaN      state          1       0    False
# 26013  2020-02-26    SP  São Paulo       city          1       0    False
# 26014  2020-02-26    SP        NaN      state          1       0    False
# 26015  2020-02-25    SP  São Paulo       city          1       0    False
# 26016  2020-02-25    SP        NaN      state          1       0    False
#
#        estimated_population_2019  city_ibge_code  \
# 26012                 45919049.0            35.0
# 26013                 12252023.0       3550308.0
# 26014                 45919049.0            35.0
# 26015                 12252023.0       3550308.0
# 26016                 45919049.0            35.0
#
#        confirmed_per_100k_inhabitants  death_rate
# 26012                         0.00218         NaN
# 26013                         0.00816         NaN
# 26014                         0.00218         NaN
# ...

# %%
df.dtypes
# Out:
# date                               object
# state                              object
# city                               object
# place_type                         object
# confirmed                           int64
# deaths                              int64
# is_last                              bool
# estimated_population_2019         float64
# city_ibge_code                    float64
# confirmed_per_100k_inhabitants    float64
# death_rate                        float64
# dtype: object

# %%
#mudando o objeto date para datetime64
df['date']= pd.to_datetime(df['date']) 
df.dtypes
# Out:
# date                              datetime64[ns]
# state                                     object
# city                                      object
# place_type                                object
# confirmed                                  int64
# deaths                                     int64
# is_last                                     bool
# estimated_population_2019                float64
# city_ibge_code                           float64
# confirmed_per_100k_inhabitants           float64
# death_rate                               float64
# dtype: object

# %%
df.columns = ['Data', 'UF', 'Município', 'Tipo_de_local', 'Casos_Confirmados', 'Mortes', 'Dados_Atualizados',
       'População_estimada_2019', 'Código IBGE',
       'Confirmados_por_100k_hab', 'Mortes/confirmados']
df.sample(5)
# Out:
#             Data  UF                Município Tipo_de_local  \
# 20419 2020-04-04  MT    Campo Novo do Parecis          city
# 9237  2020-04-16  PA  São Geraldo do Araguaia          city
# 19598 2020-04-05  BA                    Ipiaú          city
# 591   2020-04-22  MT             União do Sul          city
# 12496 2020-04-13  ES                  Castelo          city
#
#        Casos_Confirmados  Mortes  Dados_Atualizados  População_estimada_2019  \
# 20419                  1       0              False                  35360.0
# 9237                   1       0              False                  24847.0
# 19598                  6       0              False                  45873.0
# 591                    1       0               True                   3525.0
# 12496                  2       0              False                  37534.0
#
#        Código IBGE  Confirmados_por_100k_hab  Mortes/confirmados
# 20419    5102637.0                   2.82805                 NaN
# ...

# %%
df1 = df.loc[(df['Dados_Atualizados'] == True) & (df['Tipo_de_local'] == 'state') ]
df1.sample(3)
# Out:
#            Data  UF Município Tipo_de_local  Casos_Confirmados  Mortes  \
# 1016 2020-04-22  RR       NaN         state                297       3
# 1224 2020-04-22  SC       NaN         state               1115      39
# 133  2020-04-22  AM       NaN         state               2479     206
#
#       Dados_Atualizados  População_estimada_2019  Código IBGE  \
# 1016               True                 605761.0         14.0
# 1224               True                7164788.0         42.0
# 133                True                4144597.0         13.0
#
#       Confirmados_por_100k_hab  Mortes/confirmados
# 1016                  49.02924              0.0101
# 1224                  15.56222              0.0350
# 133                   59.81281              0.0831

# %%
df1.shape
# Out:
# (27, 11)

# %%
# NÚMERO DE MORTES TOTAL de coronavírus
df_uf_mortes = df1.groupby('UF').Mortes.sum()
df_uf_mortes.sort_values(ascending=False)
# Out:
# UF
# SP    1134
# RJ     490
# PE     282
# CE     221
# AM     206
# MA      76
# PR      60
# PA      53
# BA      53
# MG      47
# PB      40
# SC      39
# ES      37
# RN      29
# RS      28
# DF      25
# GO      21
# AL      20
# PI      15
# AP      14
# AC       8
# SE       7
# MS       6
# MT       6
# RO       5
# RR       3
# TO       2
# Name: Mortes, dtype: int64

# %%
# NÚMERO DE CASOS CONFIRMADOS DE CORONAVIRUS 
df_uf_cases = df1.groupby('UF').Casos_Confirmados.sum()
df_uf_cases.sort_values(ascending=False)
# Out:
# UF
# SP    15914
# RJ     5552
# CE     3682
# PE     3298
# AM     2479
# MA     1757
# BA     1645
# ES     1351
# MG     1283
# PA     1267
# SC     1115
# PR     1077
# RS      970
# DF      959
# RN      646
# AP      492
# GO      438
# PB      345
# RR      297
# AL      243
# RO      223
# PI      217
# AC      214
# MT      205
# MS      175
# SE      118
# TO       37
# Name: Casos_Confirmados, dtype: int64

# %%
#número de casos por 100 mil habitantes por UF
df_uf_pop = df1.groupby('UF').População_estimada_2019.sum()
casos_por_100k_habitantes = (df_uf_cases/df_uf_pop)*100000
casos_por_100k_habitantes.sort_values(ascending=False)
# Out:
# UF
# AM    59.812812
# AP    58.174526
# RR    49.029238
# CE    40.319410
# SP    34.656641
# PE    34.508481
# ES    33.618255
# RJ    32.157650
# DF    31.804801
# MA    24.833287
# AC    24.264827
# RN    18.421074
# SC    15.562219
# PA    14.727652
# RO    12.547652
# BA    11.060263
# PR     9.419311
# PB     8.586090
# RS     8.525794
# AL     7.281211
# PI     6.629543
# MS     6.297261
# GO     6.240780
# MG     6.060809
# MT     5.883254
# SE     5.133345
# TO     2.352394
# dtype: float64

# %%
# Evolução na cidade de São Paulo
df_sp_evo = df.loc[(df['UF'] == 'SP') & (df['Tipo_de_local'] == "state")]
df_sp_evo = df_sp_evo.reset_index()
df_sp_evo = df_sp_evo.loc[df_sp_evo['Data'] >= '2020-03-16']
df_sp_evo.head()
# Out:
#    index       Data  UF Município Tipo_de_local  Casos_Confirmados  Mortes  \
# 0   1486 2020-04-22  SP       NaN         state              15914    1134
# 1   3029 2020-04-21  SP       NaN         state              15385    1093
# 2   4530 2020-04-20  SP       NaN         state              14580    1037
# 3   5984 2020-04-19  SP       NaN         state              14267    1015
# 4   7375 2020-04-18  SP       NaN         state              13894     991
#
#    Dados_Atualizados  População_estimada_2019  Código IBGE  \
# 0               True               45919049.0         35.0
# 1              False               45919049.0         35.0
# 2              False               45919049.0         35.0
# 3              False               45919049.0         35.0
# 4              False               45919049.0         35.0
#
#    Confirmados_por_100k_hab  Mortes/confirmados
# 0                  34.65664              0.0713
# 1                  33.50461              0.0710
# ...

# %%
# Evolução das mortes de Coronavirus na cidade de São Paulo
import numpy as np
import matplotlib.pyplot as plt

# define size of figure
width_in_inches = 15
height_in_inches = 7.5
dots_per_inch = 70

plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

Data = df_sp_evo['Data']
Mortes = df_sp_evo['Mortes']

# Plot the bar graph
plot = plt.bar(Data, Mortes, color= 'red')

# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom')

# Add labels and title
plt.title('Evolução das mortes por COVID-19 no Estado de São Paulo')
plt.xlabel('Data')
plt.ylabel('Número de mortos')

plt.tight_layout()
plt.savefig("São_Paulo_deaths_evolution.png")

plt.show()

# %%
# Evolução dos casos confirmados de Coronavirus na cidade de São Paulo

# define size of figure
width_in_inches = 15
height_in_inches = 7.5
dots_per_inch = 70

plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

Data = df_sp_evo['Data']
Mortes = df_sp_evo['Casos_Confirmados']

# Plot the bar graph
plot = plt.bar(Data, Mortes, color= 'blue')

# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom')

# Add labels and title
plt.title('Evolução dos casos confirmados por COVID-19 no Estado de São Paulo')
plt.xlabel('Data')
plt.ylabel('Número de Casos Confirmados')

plt.tight_layout()
plt.savefig("São_Paulo_Cases_evolution.png")

plt.show()

# %%
# Evolução na cidade de Rio de Janeiro
df_rj_evo = df.loc[(df['UF'] == 'RJ') & (df['Tipo_de_local'] == "state")]
df_rj_evo = df_rj_evo.reset_index()
df_rj_evo = df_rj_evo.loc[df_rj_evo['Data'] >= '2020-03-16']
df_rj_evo.head()

# define size of figure
width_in_inches = 15
height_in_inches = 7.5
dots_per_inch = 70

plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

Data = df_rj_evo['Data']
Mortes = df_rj_evo['Mortes']

# Plot the bar graph
plot = plt.bar(Data, Mortes, color= 'red')

# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom')

# Add labels and title
plt.title('Evolução das mortes por COVID-19 no Estado do Rio de Janeiro')
plt.xlabel('Data')
plt.ylabel('Número de mortos')

plt.tight_layout()
plt.savefig("Rio_de_Janeiro_deaths_evolution.png")

plt.show()

# %%
# Evolução na cidade de Rio de Janeiro
df_rj_evo = df.loc[(df['UF'] == 'RJ') & (df['Tipo_de_local'] == "state")]
df_rj_evo = df_rj_evo.reset_index()
df_rj_evo = df_rj_evo.loc[df_rj_evo['Data'] >= '2020-03-16']
df_rj_evo.head()

# define size of figure
width_in_inches = 15
height_in_inches = 7.5
dots_per_inch = 70

plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

Data = df_rj_evo['Data']
Mortes = df_rj_evo['Casos_Confirmados']

# Plot the bar graph
plot = plt.bar(Data, Mortes, color= 'blue')

# Add the data value on head of the bar
for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%d' % int(height), ha='center', va='bottom')

# Add labels and title
plt.title('Evolução dos casos confirmados por COVID-19 no Estado do Rio de Janeiro')
plt.xlabel('Data')
plt.ylabel('Número de Casos Confirmados')

plt.tight_layout()
plt.savefig("Rio_de_Janeiro_Cases_evolution.png")

plt.show()
